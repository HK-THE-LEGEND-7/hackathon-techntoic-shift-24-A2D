# %%
import pandas as pd
from sklearn import linear_model

# %%
df = pd.read_csv('housing.csv')

# %%
df['mainroad'] = df['mainroad'].map({'yes': 1, 'no': 0})
df['guestroom'] = df['guestroom'].map({'yes': 1, 'no': 0})
df['basement'] = df['basement'].map({'yes': 1, 'no': 0})

# %%
x = df.drop(['price','hotwaterheating','airconditioning','furnishingstatus','prefarea'],axis='columns')

# %%
x.head()
# Out:
#    area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  parking
# 0  7420         4          2        3         1          0         0        2
# 1  8960         4          4        4         1          0         0        3
# 2  9960         3          2        2         1          0         1        2
# 3  7500         4          2        2         1          0         1        3
# 4  7420         4          1        2         1          1         1        2

# %%
y=df['price']
y.head()
# Out:
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# Name: price, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
X_test.head()
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 482  3150         3          1        2         0          0         0
# 314  4040         2          1        2         1          0         0
# 383  4500         4          2        2         1          0         1
# 487  5400         4          1        2         1          0         0
# 43   6000         4          2        4         1          0         0
#
#      parking
# 482        0
# 314        1
# 383        2
# 487        0
# 43         2

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict(X_test)
# Out:
# array([ 3010123.14085084,  3976142.51566929,  6471758.03285472,
#         4476091.78511712,  7506206.83386159,  7074922.88554174,
#         4229602.33171286,  3462841.10147934,  4872513.80174601,
#         2398236.64755847,  4182757.45546309,  2371084.04578665,
#         3865716.60193907,  3918300.36476351,  5373816.05368011,
#         2362207.77629429,  6999946.45452348,  5512597.92540061,
#         5857014.67174305,  4811506.27759249,  2929471.87040358,
#         2139488.32479175,  7033477.98407739,  4754011.61801673,
#         5714909.9365348 ,  5188908.40606773,  3776175.43060708,
#         4408279.9304282 ,  3047665.54870442,  4490226.44269083,
#         3907244.11053126,  5580822.78637067,  6177616.10018083,
#         5879590.63805534,  7374708.47085114,  5611621.86481085,
#         5447473.52040795,  2072405.42629668,  5117033.87196587,
#         4864319.83827157,  4832029.78264191,  6219678.24608123,
#         3330526.39699715,  5730680.58660549,  6219917.66454766,
#         6812551.80335025, 10127409.84966033,  4774587.19618059,
#         3200746.56272159,  5354818.22952524,  3522191.82126879,
#         5550204.35588663,  4382282.48375405,  3882910.3782469 ,
#         3287247.32904397,  5156166.48536288,  3765302.38480132,
#         3880177.41051404,  4354799.33238918,  4579517.02801055,
#         3755047.19821406,  3308011.08334006,  4926082.07448231,
#         3828856.50010341,  4676976.00250542,  5658305.48710675,
#         3063637.66739373,  2851572.96692292,  2785722.80219985,
#         7243682.85358837,  4559559.80858264,  7421267.86429679,
#         6224398.56825094,  3801549.55083953,  2647401.6991116 ,
#         3677881.93091398,  3692940.21190396,  4815253.3555595 ,
#         9337419.23867561,  4230760.04204942,  6916698.30921898,
#         6050023.42724459,  4191867.26557464,  3189135.0990213 ,
#         5391861.5397874 ,  2326726.59155353,  6091996.40660876,
#        10774827.31358506,  5595649.74612155,  3808552.87321501,
#         6619220.63178024,  3424508.01662501,  5796802.792296  ,
#         5380926.17549396,  4216795.77582698,  4019384.83991381,
#         3484411.39064362,  5993719.97958212,  5204680.31384579,
#         4894013.60825344,  4653694.70755087,  4063433.31776787,
#         5106836.12585253,  4133950.88924747,  6285965.82693326,
#         4485127.36980728,  4426766.39331251,  3817645.8983791 ,
#         4844468.24859583])

# %%
reg.score(X_test,y_test)
# Out:
# 0.6693294846972421
